# %%
import pandas  as pd
import numpy   as np

db = pd.read_excel('database_fixed.xlsx',sheet_name='db_merged_bill_demo') # Loads dataset

# %%
db.drop(labels=['ID'], axis=1, inplace=True) # Removes the column 'ID'

objs = [var for var in db.columns if db[var].dtypes=='object' and var !='default payment in Jan 2022'] # Finds the columns with 'object' type

# %%
from sklearn import preprocessing

floats = [var for var in db.columns if var != 'default payment in Jan 2022' and ( db[var].dtypes=='float64' or db[var].dtypes=='int64' or db[var].dtypes=='uint8')]
# Finds columns with numerics only

for col in floats:
    db[col] = preprocessing.scale(db[col]) # Normalized the numerical values by the scaling process. This is needed for the next analysis.

z = np.abs(db._get_numeric_data())
db = db [(z<3).all(axis=1)] # Removes normalized values larger than 3.

# %%
db = pd.get_dummies(db,columns=objs) # Creates dummies based on the groups of variables in each object

# %%
db.to_excel('data_normalized_full_dummies.xlsx', sheet_name='db_merged_bill_demo', index = False) # Stores the normalized database with dummy columns.

# %%
import seaborn as sbn # A python library for Data visualization
import matplotlib.pyplot as plt # A python library for plotting data
# %matplotlib inline 
# It directly shows plots below the code cell

# %%
# fig, ax = plt.subplots(figsize=(65,65)) # Sample figsize in inches
# color = plt.get_cmap('RdYlGn')   # default color
# color.set_bad('lightblue')    # if a value is bad the color would be lightblue instead of white
# sbn.heatmap(db.corr(method ='pearson'),annot=True,annot_kws={'size':22}, cmap=color, linewidths=.01, ax=ax)
# sbn.set(font_scale=5.5)

corr = db.corr(method ='pearson')
corr.style.background_gradient(cmap='coolwarm')


# One can change 'method=' to 'kendall' or 'spearman'. 
# Based on findings for this specific dataset, the three different methods predict the same thing.
# Out:
# <style type="text/css">
# #T_07d7b_row0_col0, #T_07d7b_row1_col1, #T_07d7b_row2_col2, #T_07d7b_row3_col3, #T_07d7b_row4_col4, #T_07d7b_row5_col5, #T_07d7b_row6_col6, #T_07d7b_row7_col7, #T_07d7b_row8_col8, #T_07d7b_row9_col9, #T_07d7b_row10_col10, #T_07d7b_row11_col11, #T_07d7b_row12_col12, #T_07d7b_row13_col13, #T_07d7b_row14_col14, #T_07d7b_row15_col15, #T_07d7b_row16_col16, #T_07d7b_row17_col17, #T_07d7b_row18_col18, #T_07d7b_row19_col19, #T_07d7b_row20_col20, #T_07d7b_row21_col21, #T_07d7b_row22_col22, #T_07d7b_row23_col23, #T_07d7b_row24_col24, #T_07d7b_row25_col25, #T_07d7b_row26_col26, #T_07d7b_row27_col27, #T_07d7b_row28_col28, #T_07d7b_row29_col29, #T_07d7b_row30_col30, #T_07d7b_row31_col31, #T_07d7b_row32_col32, #T_07d7b_row33_col33, #T_07d7b_row34_col34, #T_07d7b_row35_col35, #T_07d7b_row36_col36, #T_07d7b_row37_col37, #T_07d7b_row38_col38, #T_07d7b_row39_col39, #T_07d7b_row40_col40, #T_07d7b_row41_col41, #T_07d7b_row42_col42, #T_07d7b_row43_col43, #T_07d7b_row44_col44, #T_07d7b_row45_col45, #T_07d7b_row46_col46, #T_07d7b_row47_col47, #T_07d7b_row48_col48, #T_07d7b_row49_col49 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_07d7b_row0_col1, #T_07d7b_row29_col35, #T_07d7b_row30_col42, #T_07d7b_row31_col32, #T_07d7b_row32_col42, #T_07d7b_row33_col32, #T_07d7b_row37_col17, #T_07d7b_row37_col26, #T_07d7b_row38_col39, #T_07d7b_row39_col25, #T_07d7b_row42_col2, #T_07d7b_row42_col39 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_07d7b_row0_col2, #T_07d7b_row12_col1, #T_07d7b_row16_col17, #T_07d7b_row26_col40, #T_07d7b_row28_col33, #T_07d7b_row34_col35, #T_07d7b_row36_col40, #T_07d7b_row41_col25, #T_07d7b_row49_col0, #T_07d7b_row49_col33 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_07d7b_row0_col3, #T_07d7b_row1_col19, #T_07d7b_row26_col47, #T_07d7b_row48_col41 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_07d7b_row0_col4, #T_07d7b_row1_col18, #T_07d7b_row4_col15, #T_07d7b_row5_col16, #T_07d7b_row6_col15, #T_07d7b_row7_col16, #T_07d7b_row8_col15, #T_07d7b_row10_col15, #T_07d7b_row12_col15, #T_07d7b_row18_col15, #T_07d7b_row20_col16 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_07d7b_row0_col5, #T_07d7b_row28_col17 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_07d7b_row0_col6, #T_07d7b_row0_col49, #T_07d7b_row24_col38 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_07d7b_row0_col7, #T_07d7b_row2_col49, #T_07d7b_row33_col47, #T_07d7b_row35_col15 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_07d7b_row0_col8, #T_07d7b_row0_col15, #T_07d7b_row15_col25, #T_07d7b_row38_col24, #T_07d7b_row40_col47, #T_07d7b_row47_col37 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_07d7b_row0_col9, #T_07d7b_row15_col32, #T_07d7b_row16_col31, #T_07d7b_row24_col17, #T_07d7b_row34_col47 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_07d7b_row0_col10, #T_07d7b_row17_col24, #T_07d7b_row27_col47, #T_07d7b_row44_col47, #T_07d7b_row46_col49 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_07d7b_row0_col11, #T_07d7b_row7_col18, #T_07d7b_row8_col19, #T_07d7b_row9_col18, #T_07d7b_row10_col19, #T_07d7b_row18_col7, #T_07d7b_row18_col9, #T_07d7b_row19_col8, #T_07d7b_row19_col10, #T_07d7b_row24_col47, #T_07d7b_row40_col16 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_07d7b_row0_col12, #T_07d7b_row3_col44, #T_07d7b_row4_col46, #T_07d7b_row5_col44, #T_07d7b_row6_col46, #T_07d7b_row7_col19, #T_07d7b_row8_col18, #T_07d7b_row9_col19, #T_07d7b_row9_col44, #T_07d7b_row9_col47, #T_07d7b_row10_col18, #T_07d7b_row10_col46, #T_07d7b_row11_col44, #T_07d7b_row12_col46, #T_07d7b_row13_col47, #T_07d7b_row18_col8, #T_07d7b_row18_col10, #T_07d7b_row19_col7, #T_07d7b_row19_col9, #T_07d7b_row19_col44, #T_07d7b_row21_col46, #T_07d7b_row22_col44, #T_07d7b_row23_col47, #T_07d7b_row26_col44, #T_07d7b_row30_col46, #T_07d7b_row31_col43, #T_07d7b_row31_col46, #T_07d7b_row33_col44, #T_07d7b_row34_col44, #T_07d7b_row35_col44, #T_07d7b_row47_col44, #T_07d7b_row49_col46 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_07d7b_row0_col13, #T_07d7b_row2_col7, #T_07d7b_row2_col13, #T_07d7b_row15_col14, #T_07d7b_row16_col3, #T_07d7b_row16_col9, #T_07d7b_row16_col11, #T_07d7b_row16_col13, #T_07d7b_row16_col19, #T_07d7b_row17_col7, #T_07d7b_row17_col14, #T_07d7b_row20_col3, #T_07d7b_row20_col5, #T_07d7b_row20_col8, #T_07d7b_row20_col10, #T_07d7b_row20_col12, #T_07d7b_row20_col14, #T_07d7b_row21_col4, #T_07d7b_row21_col5, #T_07d7b_row21_col8, #T_07d7b_row21_col9, #T_07d7b_row21_col11, #T_07d7b_row21_col13, #T_07d7b_row21_col19, #T_07d7b_row22_col3, #T_07d7b_row22_col6, #T_07d7b_row22_col7, #T_07d7b_row22_col10, #T_07d7b_row22_col12, #T_07d7b_row22_col14, #T_07d7b_row22_col18, #T_07d7b_row23_col4, #T_07d7b_row23_col6, #T_07d7b_row23_col8, #T_07d7b_row23_col10, #T_07d7b_row23_col11, #T_07d7b_row23_col18, #T_07d7b_row24_col4, #T_07d7b_row24_col6, #T_07d7b_row24_col8, #T_07d7b_row24_col10, #T_07d7b_row24_col12, #T_07d7b_row24_col14, #T_07d7b_row24_col19, #T_07d7b_row25_col4, #T_07d7b_row25_col6, #T_07d7b_row25_col8, #T_07d7b_row25_col10, #T_07d7b_row25_col12, #T_07d7b_row25_col14, #T_07d7b_row26_col6, #T_07d7b_row26_col8, #T_07d7b_row26_col10, #T_07d7b_row26_col12, #T_07d7b_row26_col13, #T_07d7b_row27_col4, #T_07d7b_row27_col6, #T_07d7b_row27_col8, #T_07d7b_row27_col12, #T_07d7b_row27_col14, #T_07d7b_row28_col7, #T_07d7b_row28_col13, #T_07d7b_row28_col18, #T_07d7b_row29_col4, #T_07d7b_row29_col6, #T_07d7b_row29_col8, #T_07d7b_row29_col9, #T_07d7b_row29_col12, #T_07d7b_row29_col14, #T_07d7b_row29_col18, #T_07d7b_row30_col4, #T_07d7b_row30_col5, #T_07d7b_row30_col9, #T_07d7b_row30_col11, #T_07d7b_row30_col13, #T_07d7b_row31_col3, #T_07d7b_row31_col5, #T_07d7b_row31_col8, #T_07d7b_row31_col10, #T_07d7b_row31_col12, #T_07d7b_row31_col14, #T_07d7b_row31_col18, #T_07d7b_row32_col3, #T_07d7b_row32_col6, #T_07d7b_row32_col8, #T_07d7b_row32_col9, #T_07d7b_row32_col11, #T_07d7b_row32_col14, #T_07d7b_row33_col3, #T_07d7b_row33_col5, #T_07d7b_row33_col7, #T_07d7b_row33_col9, #T_07d7b_row33_col12, #T_07d7b_row33_col14, #T_07d7b_row33_col19, #T_07d7b_row34_col4, #T_07d7b_row34_col5, #T_07d7b_row34_col7, #T_07d7b_row34_col13, #T_07d7b_row35_col4, #T_07d7b_row35_col6, #T_07d7b_row35_col8, #T_07d7b_row35_col10, #T_07d7b_row35_col18, #T_07d7b_row36_col4, #T_07d7b_row36_col6, #T_07d7b_row36_col8, #T_07d7b_row36_col12, #T_07d7b_row36_col14, #T_07d7b_row36_col19, #T_07d7b_row37_col3, #T_07d7b_row37_col6, #T_07d7b_row37_col8, #T_07d7b_row37_col10, #T_07d7b_row37_col11, #T_07d7b_row37_col13, #T_07d7b_row38_col3, #T_07d7b_row38_col6, #T_07d7b_row38_col7, #T_07d7b_row38_col10, #T_07d7b_row38_col12, #T_07d7b_row38_col14, #T_07d7b_row38_col19, #T_07d7b_row39_col3, #T_07d7b_row39_col9, #T_07d7b_row39_col19, #T_07d7b_row40_col4, #T_07d7b_row40_col6, #T_07d7b_row40_col8, #T_07d7b_row40_col12, #T_07d7b_row40_col14, #T_07d7b_row40_col19, #T_07d7b_row41_col4, #T_07d7b_row41_col5, #T_07d7b_row41_col8, #T_07d7b_row41_col10, #T_07d7b_row41_col12, #T_07d7b_row41_col14, #T_07d7b_row41_col19, #T_07d7b_row42_col8, #T_07d7b_row42_col10, #T_07d7b_row42_col11, #T_07d7b_row42_col13, #T_07d7b_row43_col4, #T_07d7b_row43_col5, #T_07d7b_row43_col8, #T_07d7b_row43_col9, #T_07d7b_row43_col12, #T_07d7b_row43_col19, #T_07d7b_row44_col8, #T_07d7b_row44_col12, #T_07d7b_row44_col14, #T_07d7b_row44_col18, #T_07d7b_row45_col4, #T_07d7b_row45_col6, #T_07d7b_row45_col7, #T_07d7b_row45_col9, #T_07d7b_row45_col12, #T_07d7b_row45_col14, #T_07d7b_row46_col7, #T_07d7b_row46_col13, #T_07d7b_row46_col19, #T_07d7b_row47_col4, #T_07d7b_row47_col6, #T_07d7b_row47_col7, #T_07d7b_row47_col9, #T_07d7b_row47_col11, #T_07d7b_row47_col13, #T_07d7b_row47_col18, #T_07d7b_row48_col3, #T_07d7b_row48_col6, #T_07d7b_row48_col8, #T_07d7b_row48_col10, #T_07d7b_row48_col11, #T_07d7b_row48_col14, #T_07d7b_row48_col19, #T_07d7b_row49_col3, #T_07d7b_row49_col5, #T_07d7b_row49_col8, #T_07d7b_row49_col10, #T_07d7b_row49_col12, #T_07d7b_row49_col14, #T_07d7b_row49_col19 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_07d
